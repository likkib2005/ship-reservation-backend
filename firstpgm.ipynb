# %%
print("likitha")
# Out:
# likitha

# %%
print("Welcome to python")
# Out:
# Welcome to python

# %%
print(3+2)
# Out:
# 5

# %%
print("3+2")
# Out:
# 3+2

# %%
print("Hello world")
# Out:
# Hello world

# %%
print()

# %%
print("first program-python print function")
# Out:
# first program-python print function

# %%
print('what to print')
# Out:
# what to print

# %%
print('It is declared like this')
# Out:
# It is declared like this

# %%
print('print('what to print')') #in this upto close ' it is considered as one string, the rest is considered as one string
# Out:
#   Cell In[20], line 1
#     print('print('what to print')')
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print('print("what to print")')
# Out:
# print("what to print")

# %%
print("print('what to print')")
# Out:
# print('what to print')

# %%
print("hello world/n hello world/n hello world") # dont use /n use \n
# Out:
# hello world/n hello world/n hello world

# %%
print("hello world\n hello world\n hello world")
# Out:
# hello world
#  hello world
#  hello world
